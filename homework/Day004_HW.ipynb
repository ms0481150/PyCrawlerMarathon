# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
import requests
response = requests.get("https://www.dcard.tw/_api/forums/pet/posts?popular=true")
result = response.json()

#一筆資料包含的欄位
result[0]
# Out:
# {'id': 237564172,
#  'title': '我家脾氣超好的貓咪',
#  'excerpt': '我家貓咪脾氣超級好！，平常不管怎麼玩他們，他們都不會生氣！！！，完全就是天使貓咪～突然開燈，他們臉超臭🤣，當初搬家過來超害怕，但好可愛，還超愛偷看鄰居，思考中好就沒有吃罐罐，他還有一個超猛的技能：可以',
#  'anonymousSchool': False,
#  'anonymousDepartment': True,
#  'pinned': False,
#  'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#  'replyId': None,
#  'createdAt': '2021-11-29T19:20:17.063Z',
#  'updatedAt': '2021-11-29T19:33:07.008Z',
#  'commentCount': 29,
#  'likeCount': 421,
#  'withNickname': False,
#  'tags': [],
#  'topics': ['貓', '貓咪', '可愛', '米克斯'],
#  'meta': {'layout': 'classic'},
#  'forumName': '寵物',
#  'forumAlias': 'pet',
#  'nsfw': False,
#  'gender': 'F',
#  'school': '台南應用科技大學',
#  'replyTitle': None,
#  'mediaMeta': [{'id': 'ba7ea917-c6d5-43c5-8fff-92725630ab5c',
#    'url': 'https://vivid.dcard.tw/Public/e9418143-a43f-4e34-9a5a-9258d4fe934e/thumbnail.jpg',
#    'normalizedUrl': 'https://vivid.dcard.tw/Public/e9418143-a43f-4e34-9a5a-9258d4fe934e/thumbnail.jpg',
#    'thumbnail': 'https://vivid.dcard.tw/Public/e9418143-a43f-4e34-9a5a-9258d4fe934e/thumbnail.jpg',
#    'type': 'image/thumbnail',
#    'tags': ['ANNOTATED_FAILED'],
#    'createdAt': '2021-11-29T19:20:17.063Z',
#    'updatedAt': '2021-11-29T19:33:07.008Z'},
#   {'id': 'ba7ea917-c6d5-43c5-8fff-92725630ab5c',
#    'url': 'https://www.dcard.tw/v2/vivid/videos/e9418143-a43f-4e34-9a5a-9258d4fe934e?r=0.5625',
#    'normalizedUrl': '',
#    'thumbnail': 'https://vivid.dcard.tw/Public/e9418143-a43f-4e34-9a5a-9258d4fe934e/thumbnail.jpg',
#    'type': 'video/vivid',
#    'tags': ['ANNOTATED_FAILED'],
#    'createdAt': '2021-11-29T19:20:17.063Z',
#    'updatedAt': '2021-11-29T19:33:07.008Z'},
#   {'id': '48fb9641-7cc8-40c0-baec-eb4831bad1e3',
#    'url': 'https://www.dcard.tw/v2/vivid/videos/e73f2b4a-ce44-44c1-8fe4-ac7235717255?r=0.5625',
#    'normalizedUrl': '',
#    'thumbnail': 'https://vivid.dcard.tw/Public/e73f2b4a-ce44-44c1-8fe4-ac7235717255/thumbnail.jpg',
#    'type': 'video/vivid',
#    'tags': ['ANNOTATED_FAILED'],
#    'createdAt': '2021-11-29T19:20:17.063Z',
#    'updatedAt': '2021-11-29T19:33:07.008Z'},
#   {'id': '98ac423d-0679-44c1-b87b-ca3f73a9c8ab',
#    'url': 'https://www.dcard.tw/v2/vivid/videos/4fd33e2e-d93b-477e-a702-e6e1b1802d68?r=0.5625',
#    'normalizedUrl': '',
#    'thumbnail': 'https://vivid.dcard.tw/Public/4fd33e2e-d93b-477e-a702-e6e1b1802d68/thumbnail.jpg',
#    'type': 'video/vivid',
#    'tags': ['ANNOTATED_FAILED'],
#    'createdAt': '2021-11-29T19:20:17.063Z',
#    'updatedAt': '2021-11-29T19:33:07.008Z'},
#   {'id': 'cd3d6754-a1a7-40d7-a2c2-0c4f8b046056',
#    'url': 'https://i.imgur.com/1uie9JG.jpg',
#    'normalizedUrl': 'https://imgur.com/1uie9JG',
#    'thumbnail': 'https://i.imgur.com/1uie9JGl.jpg',
#    'type': 'image/imgur',
#    'tags': ['ANNOTATED'],
#    'createdAt': '2021-11-29T19:20:17.063Z',
#    'updatedAt': '2021-11-29T19:33:07.008Z',
#    'width': 1500,
#    'height': 2000},
#   {'id': '40cd7d11-4385-4e8d-9c46-f1f061654dae',
#    'url': 'https://i.imgur.com/S92n38H.jpg',
#    'normalizedUrl': 'https://imgur.com/S92n38H',
#    'thumbnail': 'https://i.imgur.com/S92n38Hl.jpg',
#    'type': 'image/imgur',
#    'tags': ['ANNOTATED'],
#    'createdAt': '2021-11-29T19:20:17.063Z',
#    'updatedAt': '2021-11-29T19:33:07.008Z',
#    'width': 2000,
#    'height': 1500},
#   {'id': '263b07f0-db1a-451d-856e-79ebf06249a7',
#    'url': 'https://i.imgur.com/uPBlQat.jpg',
#    'normalizedUrl': 'https://imgur.com/uPBlQat',
#    'thumbnail': 'https://i.imgur.com/uPBlQatl.jpg',
#    'type': 'image/imgur',
#    'tags': ['ANNOTATED'],
#    'createdAt': '2021-11-29T19:20:17.063Z',
#    'updatedAt': '2021-11-29T19:33:07.008Z',
#    'width': 2000,
#    'height': 1500},
#   {'id': '8696e794-7702-4b4a-a72d-31cfa340fff8',
#    'url': 'https://i.imgur.com/3tjhqZv.jpg',
#    'normalizedUrl': 'https://imgur.com/3tjhqZv',
#    'thumbnail': 'https://i.imgur.com/3tjhqZvl.jpg',
#    'type': 'image/imgur',
#    'tags': ['ANNOTATED'],
#    'createdAt': '2021-11-29T19:20:17.063Z',
#    'updatedAt': '2021-11-29T19:33:07.008Z',
#    'width': 1500,
#    'height': 2000}],
#  'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 407},
#   {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 13},
#   {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 1}],
#  'hidden': False,
#  'customStyle': None,
#  'isSuspiciousAccount': False,
#  'isModerator': False,
#  'layout': 'classic',
#  'spoilerAlert': False,
#  'isSelectedPost': False,
#  'enablePrivateMessage': False,
#  'totalCommentCount': 29,
#  'withImages': True,
#  'withVideos': True,
#  'media': [{'url': 'https://vivid.dcard.tw/Public/e9418143-a43f-4e34-9a5a-9258d4fe934e/thumbnail.jpg'},
#   {'url': 'https://vivid.dcard.tw/Public/e73f2b4a-ce44-44c1-8fe4-ac7235717255/thumbnail.jpg'},
#   {'url': 'https://vivid.dcard.tw/Public/4fd33e2e-d93b-477e-a702-e6e1b1802d68/thumbnail.jpg'},
#   {'url': 'https://i.imgur.com/1uie9JG.jpg'},
#   {'url': 'https://i.imgur.com/S92n38H.jpg'},
#   {'url': 'https://i.imgur.com/uPBlQat.jpg'},
#   {'url': 'https://i.imgur.com/3tjhqZv.jpg'}],
#  'reportReasonText': '',
#  'supportedReactions': None,
#  'excerptComments': [],
#  'edited': False,
#  'postAvatar': '',
#  'activityAvatar': '',
#  'verifiedBadge': False,
#  'memberType': ''}

# %%
#一次回傳的資料筆數

print(len(result))
# Out:
# 30

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
for data in result:
    print(data["title"], data["createdAt"])
    print("留言數：", data["commentCount"])
    print("按讚數：", data["likeCount"])
    print("")
# Out:
# 我家脾氣超好的貓咪 2021-11-29T19:20:17.063Z
# 留言數： 29
# 按讚數： 421
#
# 關於貓貓外出 2021-11-30T05:56:47.830Z
# 留言數： 25
# 按讚數： 339
#
# 純抱睡 2021-11-30T05:21:15.847Z
# 留言數： 16
# 按讚數： 307
#
# 我養的貓不是貓 2021-11-30T12:51:14.664Z
# 留言數： 21
# 按讚數： 256
#
# 我的貓怎麼了？？？ 2021-12-01T02:19:50.947Z
# 留言數： 30
# 按讚數： 141
#
# 家有熊出沒！😳 2021-11-30T08:05:34.232Z
# 留言數： 3
# 按讚數： 98
#
# 會不會掉下去呢？ 2021-11-30T13:28:55.421Z
# 留言數： 3
# 按讚數： 77
#
# 貓咪睡袋 2021-11-30T04:19:15.307Z
# 留言數： 5
# 按讚數： 73
#
# 貓咪跟魚之間的決鬥 2021-11-30T00:35:47.327Z
# 留言數： 2
# 按讚數： 64
#
# 台中虐貓男已在家死亡 2021-11-30T11:53:53.642Z
# 留言數： 21
# 按讚數： 63
#
# 狗狗會有憂鬱症嗎 2021-11-30T18:14:18.586Z
# 留言數： 17
# 按讚數： 42
#
# 大貓愛偷抓腳 2021-11-30T09:10:10.995Z
# 留言數： 6
# 按讚數： 39
#
# #圖 這兩隻都是我的愛❤️ 2021-11-30T14:47:42.643Z
# 留言數： 8
# 按讚數： 33
#
# 苦命小橘找家🏠 #求分享 2021-11-30T10:37:16.564Z
# 留言數： 7
# 按讚數： 32
#
# 中秋節發現的喵星人❤️ 2021-11-30T15:30:04.272Z
# 留言數： 5
# 按讚數： 25
#
# 我們常說愛要及時 卻忘記對毛家人也是 2021-11-30T10:41:15.242Z
# 留言數： 0
# 按讚數： 22
#
# 薩摩耶阿志跑跑 😆 2021-12-01T05:11:25.788Z
# 留言數： 0
# 按讚數： 16
#
# 你們的貓貓討罐罐時會很番嗎？ 2021-11-30T17:23:33.779Z
# 留言數： 5
# 按讚數： 13
#
# 太冷了吧… 2021-11-30T15:27:26.300Z
# 留言數： 2
# 按讚數： 13
#
# 小黑貓命名( ´▽｀) 2021-11-29T19:44:17.102Z
# 留言數： 13
# 按讚數： 12
#
# 齁唷人家不想回家（扭 2021-11-30T06:32:17.775Z
# 留言數： 0
# 按讚數： 11
#
# 洗澡 2021-11-29T19:16:09.792Z
# 留言數： 5
# 按讚數： 11
#
# 我與布丁的相遇 2021-12-01T00:51:17.213Z
# 留言數： 2
# 按讚數： 9
#
# #問 貓咪品種 2021-12-01T00:07:42.756Z
# 留言數： 6
# 按讚數： 9
#
# 動作慢半拍的貓(含小小妃照) 2021-12-01T03:12:00.064Z
# 留言數： 4
# 按讚數： 8
#
# 真的把通通當孩子疼 2021-11-30T12:49:27.272Z
# 留言數： 1
# 按讚數： 8
#
# 為什麼要一直舔液下啦 2021-12-01T02:35:55.621Z
# 留言數： 6
# 按讚數： 7
#
# 有認真減有差喔～2個月努力體重控制!!! 2021-11-30T12:43:32.894Z
# 留言數： 5
# 按讚數： 7
#
# 大學助理教授放任自家狗咬傷柴柴態度惡劣 2021-11-29T20:35:19.716Z
# 留言數： 2
# 按讚數： 7
#
# 你們家狗狗喜歡誰😂 2021-11-30T10:13:01.208Z
# 留言數： 0
# 按讚數： 6

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
response_unpopular = requests.get("https://www.dcard.tw/_api/forums/pet/posts?popular=false")
result_unpopular = response_unpopular.json()

# %%
#非熱門文章統計
false_comment_sum = 0
false_like_sum = 0
for data in result_unpopular:
    false_comment_sum += data["commentCount"]
    false_like_sum += data["likeCount"] 
print("非熱門文章平均留言人數：", false_comment_sum/len(result_unpopular))
print("非熱門文章平均按讚人數：", false_like_sum/len(result_unpopular))
# Out:
# 非熱門文章平均留言人數： 4.133333333333334
# 非熱門文章平均按讚人數： 13.466666666666667

# %%
#熱門文章統計
true_comment_sum = 0
true_like_sum = 0
for data in result:
    true_comment_sum += data["commentCount"]
    true_like_sum += data["likeCount"] 
print("熱門文章平均留言人數：", true_comment_sum/len(result_unpopular))
print("熱門文章平均按讚人數：", true_like_sum/len(result_unpopular))
# Out:
# 熱門文章平均留言人數： 8.3
# 熱門文章平均按讚人數： 72.3

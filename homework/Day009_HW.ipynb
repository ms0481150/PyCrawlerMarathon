# %% [markdown]
# # 其他工具：Grab、PyQuery
#
#
# * 利用 Grab 套件的存取 HTML 資源
# * 利用 PyQuery 套件的解析 HTML 格式

# %% [markdown]
# ## 作業目標
#
# 將之前用 requests + beatifulsoup 實作的方式，改寫成 grab + pyquery，並且比較有哪些地方不同。

# %% [markdown]
# ## requests + BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.ptt.cc/bbs/C_Chat/index.html"
response = requests.get(url=url)
result = BeautifulSoup(response.text)
print(type(result), result)
# Out:
# <class 'bs4.BeautifulSoup'> <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 C_Chat 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/C_Chat/index.html"><span class="board-label">看板 </span>C_Chat</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="main-container">
# <div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn selected" href="/bbs/C_Chat/index.html">看板</a>
# <a class="btn" href="/man/C_Chat/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/C_Chat/index1.html">最舊</a>
# <a class="btn wide" href="/bbs/C_Chat/index17608.html">‹ 上頁</a>
# <a class="btn wide disabled">下頁 ›</a>
# <a class="btn wide" href="/bbs/C_Chat/index.html">最新</a>
# </div>
# </div>
# </div>
# <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# <form action="search" id="search-bar" type="get">
# <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
# </form>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">14</span></div>
# <div class="title">
# <a href="/bbs/C_Chat/M.1639036651.A.928.html">[情報] 東映動畫開版權砲，歐美動漫Youtuber 150</a>
# </div>
# <div class="meta">
# <div class="author">joug</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/C_Chat/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+%E6%9D%B1%E6%98%A0%E5%8B%95%E7%95%AB%E9%96%8B%E7%89%88%E6%AC%8A%E7%A0%B2%EF%BC%8C%E6%AD%90%E7%BE%8E%E5%8B%95%E6%BC%ABYoutuber+150">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/C_Chat/search?q=author%3Ajoug">搜尋看板內 joug 的文章</a></div>
# </div>
# </div>
# <div class="date">12/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">17</span></div>
# <div class="title">
# <a href="/bbs/C_Chat/M.1639036920.A.FF2.html">[縱容] 任天堂Switch在義大利和歐洲銷量再創新高</a>
# </div>
# <div class="meta">
# <div class="author">ryoma1</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/C_Chat/search?q=thread%3A%5B%E7%B8%B1%E5%AE%B9%5D+%E4%BB%BB%E5%A4%A9%E5%A0%82Switch%E5%9C%A8%E7%BE%A9%E5%A4%A7%E5%88%A9%E5%92%8C%E6%AD%90%E6%B4%B2%E9%8A%B7%E9%87%8F%E5%86%8D%E5%89%B5%E6%96%B0%E9%AB%98">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/C_Chat/search?q=author%3Aryoma1">搜尋看板內 ryoma1 的文章</a></div>
# </div>
# </div>
# <div class="date">12/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">3</span></div>
# <div class="title">
# <a href="/bbs/C_Chat/M.1639037141.A.4B6.html">[閒聊] 轉生蜘蛛 漫畫55-1</a>
# </div>
# <div class="meta">
# <div class="author">dhero</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/C_Chat/search?q=thread%3A%5B%E9%96%92%E8%81%8A%5D+%E8%BD%89%E7%94%9F%E8%9C%98%E8%9B%9B+%E6%BC%AB%E7%95%AB55-1">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/C_Chat/search?q=author%3Adhero">搜尋看板內 dhero 的文章</a></div>
# </div>
# </div>
# <div class="date">12/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">5</span></div>
# <div class="title">
# <a href="/bbs/C_Chat/M.1639037170.A.EF2.html">[閒聊] 有哪些VTUBER開過不開台耐久</a>
# </div>
# <div class="meta">
# <div class="author">Jie0724</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/C_Chat/search?q=thread%3A%5B%E9%96%92%E8%81%8A%5D+%E6%9C%89%E5%93%AA%E4%BA%9BVTUBER%E9%96%8B%E9%81%8E%E4%B8%8D%E9%96%8B%E5%8F%B0%E8%80%90%E4%B9%85">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/C_Chat/search?q=author%3AJie0724">搜尋看板內 Jie0724 的文章</a></div>
# </div>
# </div>
# <div class="date">12/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">4</span></div>
# <div class="title">
# <a href="/bbs/C_Chat/M.1639037186.A.A65.html">[實況] 第596天，30歲辭職 跑去做遊戲好嗎？</a>
# </div>
# <div class="meta">
# <div class="author">Dinaya</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/C_Chat/search?q=thread%3A%5B%E5%AF%A6%E6%B3%81%5D+%E7%AC%AC596%E5%A4%A9%EF%BC%8C30%E6%AD%B2%E8%BE%AD%E8%81%B7+%E8%B7%91%E5%8E%BB%E5%81%9A%E9%81%8A%E6%88%B2%E5%A5%BD%E5%97%8E%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/C_Chat/search?q=author%3ADinaya">搜尋看板內 Dinaya 的文章</a></div>
# </div>
# </div>
# <div class="date">12/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">34</span></div>
# <div class="title">
# <a href="/bbs/C_Chat/M.1639037380.A.E26.html">[FF14] 到底該怎麼用中文稱6.0新職業Reaper</a>
# </div>
# <div class="meta">
# <div class="author">GrimmNotes</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/C_Chat/search?q=thread%3A%5BFF14%5D+%E5%88%B0%E5%BA%95%E8%A9%B2%E6%80%8E%E9%BA%BC%E7%94%A8%E4%B8%AD%E6%96%87%E7%A8%B16.0%E6%96%B0%E8%81%B7%E6%A5%ADReaper">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/C_Chat/search?q=author%3AGrimmNotes">搜尋看板內 GrimmNotes 的文章</a></div>
# </div>
# </div>
# <div class="date">12/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">7</span></div>
# <div class="title">
# <a href="/bbs/C_Chat/M.1639037390.A.7C2.html">[閒聊] LiSA Uru X #HoshiStar - Saikai(再会)</a>
# </div>
# <div class="meta">
# <div class="author">thelittleone</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/C_Chat/search?q=thread%3A%5B%E9%96%92%E8%81%8A%5D+LiSA+Uru+X+%23HoshiStar+-+Saikai%28%E5%86%8D%E4%BC%9A%29">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/C_Chat/search?q=author%3Athelittleone">搜尋看板內 thelittleone 的文章</a></div>
# </div>
# </div>
# <div class="date">12/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/C_Chat/M.1639037413.A.35D.html">Fw: [情報] GBO2更新：女武神+免費50抽</a>
# </div>
# <div class="meta">
# <div class="author">uei1201</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/C_Chat/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+GBO2%E6%9B%B4%E6%96%B0%EF%BC%9A%E5%A5%B3%E6%AD%A6%E7%A5%9E%2B%E5%85%8D%E8%B2%BB50%E6%8A%BD">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/C_Chat/search?q=author%3Auei1201">搜尋看板內 uei1201 的文章</a></div>
# </div>
# </div>
# <div class="date">12/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/C_Chat/M.1639037834.A.AF4.html">[閒聊] 朋友遊戲  95  友一求救了</a>
# </div>
# <div class="meta">
# <div class="author">MiharuHubby</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/C_Chat/search?q=thread%3A%5B%E9%96%92%E8%81%8A%5D+%E6%9C%8B%E5%8F%8B%E9%81%8A%E6%88%B2++95++%E5%8F%8B%E4%B8%80%E6%B1%82%E6%95%91%E4%BA%86">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/C_Chat/search?q=author%3AMiharuHubby">搜尋看板內 MiharuHubby 的文章</a></div>
# </div>
# </div>
# <div class="date">12/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/C_Chat/M.1639037890.A.7BC.html">[閒聊] 推主自製《薩爾達》海利亞之盾背包給小孩</a>
# </div>
# <div class="meta">
# <div class="author">dogluckyno1</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/C_Chat/search?q=thread%3A%5B%E9%96%92%E8%81%8A%5D+%E6%8E%A8%E4%B8%BB%E8%87%AA%E8%A3%BD%E3%80%8A%E8%96%A9%E7%88%BE%E9%81%94%E3%80%8B%E6%B5%B7%E5%88%A9%E4%BA%9E%E4%B9%8B%E7%9B%BE%E8%83%8C%E5%8C%85%E7%B5%A6%E5%B0%8F%E5%AD%A9">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/C_Chat/search?q=author%3Adogluckyno1">搜尋看板內 dogluckyno1 的文章</a></div>
# </div>
# </div>
# <div class="date">12/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-list-sep"></div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">14</span></div>
# <div class="title">
# <a href="/bbs/C_Chat/M.1634992132.A.1D5.html">[公告] C_Chat板板規 v.16.6</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/C_Chat/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+C_Chat%E6%9D%BF%E6%9D%BF%E8%A6%8F+v.16.6">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/C_Chat/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date">10/23</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">11</span></div>
# <div class="title">
# <a href="/bbs/C_Chat/M.1630797828.A.6AD.html">[公告] 看板活動公告彙整 ＆ 置底推文閒聊區</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/C_Chat/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E7%9C%8B%E6%9D%BF%E6%B4%BB%E5%8B%95%E5%85%AC%E5%91%8A%E5%BD%99%E6%95%B4+%EF%BC%86+%E7%BD%AE%E5%BA%95%E6%8E%A8%E6%96%87%E9%96%92%E8%81%8A%E5%8D%80">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/C_Chat/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date"> 9/05</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/C_Chat/M.1638881125.A.A9B.html">[公告] C_Chat 板 開始舉辦樂透!</a>
# </div>
# <div class="meta">
# <div class="author">laptic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/C_Chat/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+C_Chat+%E6%9D%BF+%E9%96%8B%E5%A7%8B%E8%88%89%E8%BE%A6%E6%A8%82%E9%80%8F%21">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/C_Chat/search?q=author%3Alaptic">搜尋看板內 laptic 的文章</a></div>
# </div>
# </div>
# <div class="date">12/07</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">20</span></div>
# <div class="title">
# <a href="/bbs/C_Chat/M.1638812813.A.A1A.html">[活動][板慶] 希洽十五歲ANSI徵稿</a>
# </div>
# <div class="meta">
# <div class="author">zMidTwo5566</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/C_Chat/search?q=thread%3A%5B%E6%B4%BB%E5%8B%95%5D%5B%E6%9D%BF%E6%85%B6%5D+%E5%B8%8C%E6%B4%BD%E5%8D%81%E4%BA%94%E6%AD%B2ANSI%E5%BE%B5%E7%A8%BF">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/C_Chat/search?q=author%3AzMidTwo5566">搜尋看板內 zMidTwo5566 的文章</a></div>
# </div>
# </div>
# <div class="date">12/07</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">14</span></div>
# <div class="title">
# <a href="/bbs/C_Chat/M.1631543713.A.CE4.html">[21秋] 秋番各作品首播時間</a>
# </div>
# <div class="meta">
# <div class="author">SaberTheBest</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/C_Chat/search?q=thread%3A%5B21%E7%A7%8B%5D+%E7%A7%8B%E7%95%AA%E5%90%84%E4%BD%9C%E5%93%81%E9%A6%96%E6%92%AD%E6%99%82%E9%96%93">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/C_Chat/search?q=author%3ASaberTheBest">搜尋看板內 SaberTheBest 的文章</a></div>
# </div>
# </div>
# <div class="date"> 9/13</div>
# <div class="mark">M</div>
# </div>
# </div>
# </div>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# </body>
# </html>

# %% [markdown]
# ## Grab + PyQuery

# %%
from grab import Grab
from pyquery import PyQuery as pq
g = Grab()
response = g.go("https://www.ptt.cc/bbs/C_Chat/index.html")
result = response.body
doc = pq(result)
title = doc("title")
print(type(title), title.text())
# Out:
# <class 'pyquery.pyquery.PyQuery'> 看板 C_Chat 文章列表 - 批踢踢實業坊

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://github.com/new"
response = requests.get(url=url)
result = BeautifulSoup(response.text, "html5lib")
content = result.text.replace("\n", "")
content
# Out:
# '                                                                                                                                                                                                                                                                                                                                Sign in to GitHub · GitHub                                                                                                                                                                                                                              Skip to content                                                              GitHub no longer supports this web browser.                  Learn more about the browsers we support.                                                                                                    Sign in to GitHub                                                {{ message }}                                                                    User
# ...

# %% [markdown]
# * 登入前的cookies
# ![登入前的cookies](https://i.imgur.com/ofyFZry.png)
#
# * 登入後的cookies
# ![登入後的cookies](https://i.imgur.com/33DRnwn.png)

# %%
# 帶入cookies

cookies = {
    "dotcom_user":"ms0481150",
    "_octo":"GH1.1.1602507724.1634492654",
    "logged_in":"yes",
    "_gh_sess":"f3twzccev3s93zXxeY3SQHiad2zsSieCcdQPeTzvLtUOpZ9oDz0Pj2SJN9swgXGzfHtBEXAt9yltp8wU4k7GgnHYB%2Bw0zgVGnns0r%2FLwc8z6XxjocmgMuXQi3T0qJQv4UBB2jVC1Dsh9gZOVmndrWwp0J8un%2FVUnTVkJreP6cg7lKoFQNyAVyglMRDCvnCyU--51w0ssaDnQSgKKrf--XcDtvcAlaCFFDyEW5g%2FMMg%3D%3D",
    "has_recent_activity":"1",
    "__Host-user_session_same_site":"2Wlgx47QdAcMN2gQO4eNpabIo9hCXXBp17YhZY7asLr5oUB9",
    "user_session":"2Wlgx47QdAcMN2gQO4eNpabIo9hCXXBp17YhZY7asLr5oUB9",
    "tz":"Asia%2FTaipei",
    "_device_id":"7ef65c1e0bdd1b04e36cb37073dfd31f"
}

url = "https://github.com/new"
response = requests.get(url=url, cookies=cookies)
result = BeautifulSoup(response.text, "html5lib")
content = result.text.replace("\n", "")
content
# Out:
# '                                                                                                                                                                                                                                                                                                                                Create a New Repository                                                                                                                                                                                                "all"                                              Skip to content                                                                                                                                                                                                                                              Search                    All GitHub            ↵              Jump to      ↵            No suggested jump to results                                         
# ...

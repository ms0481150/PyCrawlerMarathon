# %% [markdown]
# ## 作業目標
#
# * 讀讀看「test」資料夾下的圖檔！
# * 像 test/test2.png 這種複雜的圖片怎麼辦？

# %% [markdown]
# ### 讀讀看「test」資料夾下的圖檔！

# %%
import pytesseract
from PIL import Image

# 有關pytestseract會報錯"tesseract is not installed or it's not in your PATH. See README file for more information."
# 解決方法：
# https://stackoverflow.com/questions/50951955/pytesseract-tesseractnotfound-error-tesseract-is-not-installed-or-its-not-i
#
pytesseract.pytesseract.tesseract_cmd = r'C:\Users\GSX-401FW\AppData\Local\Programs\Tesseract-OCR\tesseract.exe'

# %%
img1 = Image.open("./Data/test1.png")
img2 = Image.open("./Data/test2.png")
img3 = Image.open("./Data/code.png")

img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=954x362 at 0x1FD2397BA90>

# %%
code = pytesseract.image_to_string(img1)
print(code)
# Out:
# 619121

# %%
img2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=154x64 at 0x1FD2395B700>

# %%
code = pytesseract.image_to_string(img2)
print(code)
# Out:
# 1413

# %%
img3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=640x377 at 0x1FD2395B0D0>

# %%
code = pytesseract.image_to_string(img3)
print(code)
# Out:
# Hello World-

# %% [markdown]
# ### 像 test/test2.png 這種複雜的圖片怎麼辦？

# %%
img4= Image.open("./Data/test2.png").convert("L")  # 轉灰階
img4
# Out:
# <PIL.Image.Image image mode=L size=154x64 at 0x1FD21489250>

# %%
code = pytesseract.image_to_string(img4)
print(code)
# Out:
# 4413

# %%
# 用別的圖片試試

img5 = Image.open("./Data/meme1.jpg")
img5
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=880x685 at 0x1FD211FCD30>

# %%
code = pytesseract.image_to_string(img5)
print(code)
# Out:
# How to make meetings shorter:
#
# aay

# %%
img6 = Image.open("./Data/meme2.jpg").convert("L")
img6
# Out:
# <PIL.Image.Image image mode=L size=485x513 at 0x1FD2149AA90>

# %%
code = pytesseract.image_to_string(img6)
print(code)
# Out:
# My code never
# has bugs
# y Itjust develops
# A: om unexpected
# features.
